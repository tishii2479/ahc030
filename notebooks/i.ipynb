# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../log/database.csv")
input_df = pd.read_csv("../log/input.csv")

# %%
solver_df = pd.merge(df[df.solver_version == "data-collection-3"], input_df, how="left", on="input_file")
solver_df
# Out:
#              input_file     solver_version      score  duration  query_count  \
# 0     tools/in/0000.txt  data-collection-3   0.707107    3.1395            7
# 1     tools/in/0001.txt  data-collection-3   6.337479   16.4577           48
# 2     tools/in/0002.txt  data-collection-3   4.230085   12.1795           30
# 3     tools/in/0003.txt  data-collection-3   2.356660    9.1322           20
# 4     tools/in/0004.txt  data-collection-3  25.692689   27.5753          153
# ...                 ...                ...        ...       ...          ...
# 2995  tools/in/2995.txt  data-collection-3  18.666667   24.2327          113
# 2996  tools/in/2996.txt  data-collection-3  15.166667   22.2086           92
# 2997  tools/in/2997.txt  data-collection-3  22.059481   28.2898          169
# 2998  tools/in/2998.txt  data-collection-3   2.864358    9.1276           20
# 2999  tools/in/2999.txt  data-collection-3  38.078664   34.4255          308
#
#        n   m   eps     dense
# 0     15   2  0.01  0.168889
# 1     13   6  0.04  0.159763
# 2     13   2  0.07  0.402367
# 3     19   2  0.08  0.315789
# 4     16   8  0.14  0.367188
# ...   ..  ..   ...       ...
# 2995  12   6  0.10  0.333333
# 2996  13   4  0.11  0.284024
# 2997  18   9  0.09  0.225309
# 2998  11   3  0.05  0.272727
# 2999  19  16  0.08  0.260388
#
# [3000 rows x 9 columns]

# %%
solver_df[["n", "m", "eps"]].value_counts()
# Out:
# n   m   eps
# 11  4   0.18    9
# 10  4   0.07    8
#         0.16    8
# 12  4   0.08    8
# 11  5   0.20    7
#                ..
# 17  3   0.11    1
#         0.14    1
#         0.15    1
#         0.16    1
# 20  20  0.20    1
# Name: count, Length: 1536, dtype: int64

# %%
a = solver_df[(solver_df.n == 10) & (solver_df.m == 4) & (solver_df.eps == 0.07)]
a.plot.scatter("dense", "query_count")
# Out:
# <AxesSubplot:xlabel='dense', ylabel='query_count'>

# %%
a
# Out:
#              input_file     solver_version      score  duration  query_count  \
# 124   tools/in/0124.txt  data-collection-3   8.833333   17.1566           54
# 227   tools/in/0227.txt  data-collection-3   8.833333   17.1737           54
# 963   tools/in/0963.txt  data-collection-3   4.833333   12.1185           30
# 1199  tools/in/1199.txt  data-collection-3   7.000000   15.2491           43
# 1796  tools/in/1796.txt  data-collection-3  12.333333   20.2951           75
# 1861  tools/in/1861.txt  data-collection-3  13.666667   21.2376           83
# 2120  tools/in/2120.txt  data-collection-3   7.833333   16.2032           48
# 2356  tools/in/2356.txt  data-collection-3   7.833333   16.1365           48
#
#        n  m   eps  dense
# 124   10  4  0.07   0.40
# 227   10  4  0.07   0.20
# 963   10  4  0.07   0.40
# 1199  10  4  0.07   0.36
# 1796  10  4  0.07   0.20
# 1861  10  4  0.07   0.20
# 2120  10  4  0.07   0.29
# 2356  10  4  0.07   0.44
